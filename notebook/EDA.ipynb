# %%
import pandas as pd
import sys
sys.path.insert(0, '/10 A KAI 2/week11/Time_Series_Forecasting_for_Portfolio_Management')

# %%
from script.EDA import EDA

# %%
merged = pd.read_csv('./financial_data/merged_financial_data.csv')

# %%
all_data = EDA(merged)

# %%
all_data.get_summary_stats('TSLA')
# Out:
#                                 Date    Adj Close        Close         High  \
# count                           2474  2474.000000  2474.000000  2474.000000
# mean   2019-12-01 07:38:04.559417856   111.438965   111.438965   113.895836
# min              2015-01-02 00:00:00     9.578000     9.578000    10.331333
# 25%              2017-06-16 18:00:00    17.066167    17.066167    17.368167
# 50%              2019-11-30 12:00:00    25.043000    25.043000    25.279000
# 75%              2022-05-15 06:00:00   216.865002   216.865002   221.910004
# max              2024-10-30 00:00:00   409.970001   409.970001   414.496674
# std                              NaN   110.120450   110.120450   112.643277
#
#                Low         Open        Volume
# count  2474.000000  2474.000000  2.474000e+03
# mean    108.869421   111.461872  1.125745e+08
# min       9.403333     9.488000  1.062000e+07
# 25%      16.790167    17.058499  6.682590e+07
# 50%      24.462334    24.986667  9.289395e+07
# ...

# %%
all_data.get_summary_stats('BND')
# Out:
#                                 Date    Adj Close        Close         High  \
# count                           2474  2474.000000  2474.000000  2474.000000
# mean   2019-12-01 07:38:04.559417856    70.089251    80.316039    80.431152
# min              2015-01-02 00:00:00    62.637589    68.040001    68.379997
# 25%              2017-06-16 18:00:00    66.314058    76.379997    76.674999
# 50%              2019-11-30 12:00:00    68.888950    81.410004    81.519997
# 75%              2022-05-15 06:00:00    73.807495    84.010002    84.167500
# max              2024-10-30 00:00:00    79.812935    89.480003    89.589996
# std                              NaN     4.889919     5.097592     5.082268
#
#                Low         Open        Volume
# count  2474.000000  2474.000000  2.474000e+03
# mean     80.198464    80.319968  4.169014e+06
# min      67.989998    68.080002  0.000000e+00
# 25%      76.265001    76.502501  2.024900e+06
# 50%      81.300003    81.410004  3.710900e+06
# ...

# %%
all_data.get_summary_stats('SPY')
# Out:
#                                 Date    Adj Close        Close         High  \
# count                           2474  2474.000000  2474.000000  2474.000000
# mean   2019-12-01 07:38:04.559417856   310.253153   330.623634   332.368856
# min              2015-01-02 00:00:00   157.328598   182.860001   184.100006
# 25%              2017-06-16 18:00:00   214.822338   242.130001   243.380005
# 50%              2019-11-30 12:00:00   275.812302   298.089996   299.324997
# 75%              2022-05-15 06:00:00   402.297516   416.212502   418.242500
# max              2024-10-30 00:00:00   584.590027   584.590027   586.119995
# std                              NaN   111.250656   103.324179   103.840765
#
#                Low         Open        Volume
# count  2474.000000  2474.000000  2.474000e+03
# mean    328.614426   330.570376  8.810268e+07
# min     181.020004   182.339996  2.027000e+07
# 25%     240.692501   242.302498  5.960170e+07
# 50%     296.804993   298.095001  7.696935e+07
# ...

# %%
all_data.data_types()
# Out:
#               Column       Data Type
# Date            Date  datetime64[ns]
# Adj Close  Adj Close         float64
# Close          Close         float64
# High            High         float64
# Low              Low         float64
# Open            Open         float64
# Volume        Volume           int64
# Ticker        Ticker          object

# %%
all_data.missing_percentage()
# Out:
#               Column  Missing Percentage
# Date            Date                 0.0
# Adj Close  Adj Close                 0.0
# Close          Close                 0.0
# High            High                 0.0
# Low              Low                 0.0
# Open            Open                 0.0
# Volume        Volume                 0.0
# Ticker        Ticker                 0.0

# %%
all_data.trend_analysis_close_price()

# %% [markdown]
# ### Market Dynamics
# - TSLA's high volatility contrasts with the steadiness of SPY and BND, illustrating the difference in risk and return profiles between individual stocks, equity indices, and bonds.
# ### Investment Strategies
# - **TSLA**: Suitable for investors seeking growth and higher returns but requiring tolerance for significant price swings.
# - **SPY**: Offers balanced growth, appealing to those looking for moderate risk and return.
# - **BND**: Provides stability, making it ideal for risk-averse investors.
# #### Economic Events
# - Events like the 2020 pandemic impact the equity market more significantly than bonds. This is evident in the pronounced dip in SPY and TSLA compared to the flat trajectory of BND.

# %%
all_data.daily_percentage_change()

# %% [markdown]
# ###  Volatility Over Time
# The chart illustrates the **daily percentage change** for TSLA, SPY, and BND from 2015 to 2025, highlighting the following pattern
# 1. **TSLA**: Exhibits significant fluctuations, indicating high volatility and risk.
# 2. **SPY**: Shows moderate and consistent changes, representing balanced equity performance.
# 3. **BND**: Demonstrates minimal variation, reflecting the stability of bonds.
# #### Key Insights:
# - TSLA's spikes underline its potential for high returns alongside substantial risk.
# - SPY maintains a steady trend, suitable for balanced growth strategies.
# - BND's near-flat trajectory appeals to conservative, risk-averse investors.

# %%
all_data.rolling_analysis()
# Out:
# d:\10 A KAI 2/week11/Time_Series_Forecasting_for_Portfolio_Management\script\EDA.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Rolling Mean'] = ticker_data['Close'].rolling(window=self.window).mean()
# d:\10 A KAI 2/week11/Time_Series_Forecasting_for_Portfolio_Management\script\EDA.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Rolling Std'] = ticker_data['Close'].rolling(window=self.window).std()
# ...

# %%
all_data.outlier_detection_and_analysis()
# Out:
# Number of outliers per ticker:
# Ticker
# BND     0
# SPY     0
# TSLA    0
# dtype: int64

# %% [markdown]
# ### outlier detection usibg IQR

# %%
all_data.process_and_visualize_outliers()
# Out:
# Outlier Percentage for 'Daily Return Close' by Ticker:
# Ticker
# BND      0.282943
# SPY      8.084074
# TSLA    49.555376
# Name: Outlier Close, dtype: float64
#
# Outlier Percentage for 'Daily Return Low' by Ticker:
# Ticker
# BND      0.323363
# SPY      6.952304
# TSLA    48.181083
# Name: Outlier Low, dtype: float64

# %% [markdown]
# ### Seasonality and Trends

# %%
all_data.decompose_time_series()

# %% [markdown]
# #### Analyze Volatility

# %%
all_data.analyze_volatility()
# Out:
# d:\10 A KAI 2/week11/Time_Series_Forecasting_for_Portfolio_Management\script\EDA.py:258: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Rolling Mean'] = ticker_data['Close'].rolling(window=window).mean()
# d:\10 A KAI 2/week11/Time_Series_Forecasting_for_Portfolio_Management\script\EDA.py:259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Rolling Std'] = ticker_data['Close'].rolling(window=window).std()
# ...

# %% [markdown]
# ### Calculate VaR ratio and Sharp ratio

# %%
# Summarize key insights for Tesla's stock
all_data.document_key_insights()
# Out:
# Overall Direction of Tesla's Stock Price: 4296.46%
#
# Fluctuations in Daily Returns:
# count    7419.000000
# mean        0.074592
# std         2.175802
# min       -21.062824
# 25%        -0.392380
# 50%         0.034097
# 75%         0.493968
# max        21.919035
# Name: Daily Returns, dtype: float64
# Value at Risk (VaR): -0.90%
# Sharpe Ratio: 0.03
